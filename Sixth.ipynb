# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 8 possible package resolutions (only showing differing packages):
#   - anaconda::ca-certificates-2019.5.15-0, anaconda::certifi-2019.6.16-py37_0, anaconda::openssl-1.1.1c-he774522_1
#   - anaconda::ca-certificates-2019.5.15-0, anaconda::openssl-1.1.1c-he774522_1, defaults::certifi-2019.6.16-py37_0
#   - anaconda::certifi-2019.6.16-py37_0, anaconda::openssl-1.1.1c-he774522_1, defaults::ca-certificates-2019.5.15-0
#   - anaconda::openssl-1.1.1c-he774522_1, defaults::ca-certificates-2019.5.15-0, defaults::certifi-2019.6.16-py37_0
#   - anaconda::certifi-2019.6.16-py37_0, defaults::ca-certificates-2019.5.15-0, defaults::openssl-1.1.1c-he774522_1
#   - defaults::ca-certificates-2019.5.15-0, defaults::certifi-2019.6.16-py37_0, defaults::openssl-1.1.1c-he774522_1
#   - anaconda::ca-certificates-2019.5.15-0, anaconda::certifi-2019.6.16-py37_0, defaults::openssl-1.1.1c-he774522_1
#   - anaconda::ca-certificates-2019.5.15-0, defaults::certifi-2019.6.16-py37_0, defaults::openssl-1.1.1c-he774522_1done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 8 possible package resolutions (only showing differing packages):
#   - anaconda::ca-certificates-2019.5.15-0, anaconda::certifi-2019.6.16-py37_0, anaconda::openssl-1.1.1c-he774522_1
#   - anaconda::ca-certificates-2019.5.15-0, anaconda::certifi-2019.6.16-py37_0, defaults::openssl-1.1.1c-he774522_1
#   - anaconda::ca-certificates-2019.5.15-0, anaconda::openssl-1.1.1c-he774522_1, defaults::certifi-2019.6.16-py37_0
#   - anaconda::ca-certificates-2019.5.15-0, defaults::certifi-2019.6.16-py37_0, defaults::openssl-1.1.1c-he774522_1
#   - anaconda::openssl-1.1.1c-he774522_1, defaults::ca-certificates-2019.5.15-0, defaults::certifi-2019.6.16-py37_0
#   - defaults::ca-certificates-2019.5.15-0, defaults::certifi-2019.6.16-py37_0, defaults::openssl-1.1.1c-he774522_1
#   - anaconda::certifi-2019.6.16-py37_0, anaconda::openssl-1.1.1c-he774522_1, defaults::ca-certificates-2019.5.15-0
#   - anaconda::certifi-2019.6.16-py37_0, defaults::ca-certificates-2019.5.15-0, defaults::openssl-1.1.1c-he774522_1done
#
# # All requested packages already installed.

# %%
ClIENT_ID = 'QTM50SKMXJ1SVI5NF0ZNAFVGLQQ5TQS4GC0BQ3YPZKBHGBRE' # your Foursquare ID
ClIENT_SECRET = 'BY42AUCWXDZ2AIGL11FSR3LYROTHMIATTTGS14GPT2SHOIQK' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 35

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QTM50SKMXJ1SVI5NF0ZNAFVGLQQ5TQS4GC0BQ3YPZKBHGBRE
# CLIENT_SECRET:BY42AUCWXDZ2AIGL11FSR3LYROTHMIATTTGS14GPT2SHOIQK

# %%
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.653963 -79.387207

# %%
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QTM50SKMXJ1SVI5NF0ZNAFVGLQQ5TQS4GC0BQ3YPZKBHGBRE&client_secret=BY42AUCWXDZ2AIGL11FSR3LYROTHMIATTTGS14GPT2SHOIQK&ll=43.653963,-79.387207&v=20180605&query=Hotel&radius=500&limit=35'

# %%
results = requests.get(url).json()
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '56aa371be4b08b9a8d5734cf', 'name': 'B...    False
#
#                          id       location.address location.cc location.city  \
# 0  4ab2d511f964a5209b6c20e3  123 Queen Street West          CA       Toronto
# 1  4b68aed1f964a520de862be3         194 Queen St W          CA       Toronto
# 2  52ce14b0498e50457ce11780    108 Chestnut Street          CA       Toronto
# 3  4f343a31e4b0230a3b337a90         123 Test Drive          CA       Toronto
# 4  5545d07e498e2facac03f666  123 Queen Street West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada          at York St.                390
# 1           Canada  Queen & St. Patrick                400
# 2           Canada          Dundas St W                124
# 3           Canada      at somewhere St                500
# 4           Canada        at Bay Street                376
#
#                            location.formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [108 Chestnut Street (Dundas St W), Toronto ON...
# 3  [123 Test Drive (at somewhere St), Toronto ON ...
# 4  [123 Queen Street West (at Bay Street), Toront...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.6511441, 'lng'...     43.651144
# 1  [{'label': 'display', 'lat': 43.65050475544005...     43.650505
# 2  [{'label': 'display', 'lat': 43.6546083, 'lng'...     43.654608
# 3  [{'label': 'display', 'lat': 43.658434, 'lng':...     43.658434
# 4  [{'label': 'display', 'lat': 43.65119976208405...     43.651200
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.384329                   NaN             M5H 2M9             ON
# 1    -79.388577                   NaN             M5V 1Z1             ON
# 2    -79.385942                   NaN             M5G 1R3             ON
# 3    -79.387894                   NaN             M2M 2M2             ON
# 4    -79.384520    Financial District                 NaN             ON
#
#                                              name    referralId venuePage.id
# 0                   Sheraton Centre Toronto Hotel  v-1568536538          NaN
# 1                  The Rex Hotel Jazz & Blues Bar  v-1568536538     62225795
# 2     DoubleTree by Hilton Hotel Toronto Downtown  v-1568536538          NaN
# 3                                  VFM Test Hotel  v-1568536538          NaN
# 4  Sheraton Centre Toronto Hotel - Grand Ballroom  v-1568536538          NaN

# %%
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                              name categories  \
# 0                   Sheraton Centre Toronto Hotel      Hotel
# 1                  The Rex Hotel Jazz & Blues Bar  Jazz Club
# 2     DoubleTree by Hilton Hotel Toronto Downtown      Hotel
# 3                                  VFM Test Hotel      Hotel
# 4  Sheraton Centre Toronto Hotel - Grand Ballroom   Ballroom
#
#                  address  cc     city country          crossStreet  distance  \
# 0  123 Queen Street West  CA  Toronto  Canada          at York St.       390
# 1         194 Queen St W  CA  Toronto  Canada  Queen & St. Patrick       400
# 2    108 Chestnut Street  CA  Toronto  Canada          Dundas St W       124
# 3         123 Test Drive  CA  Toronto  Canada      at somewhere St       500
# 4  123 Queen Street West  CA  Toronto  Canada        at Bay Street       376
#
#                                     formattedAddress  \
# 0  [123 Queen Street West (at York St.), Toronto ...
# 1  [194 Queen St W (Queen & St. Patrick), Toronto...
# 2  [108 Chestnut Street (Dundas St W), Toronto ON...
# 3  [123 Test Drive (at somewhere St), Toronto ON ...
# 4  [123 Queen Street West (at Bay Street), Toront...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.6511441, 'lng'...  43.651144 -79.384329
# 1  [{'label': 'display', 'lat': 43.65050475544005...  43.650505 -79.388577
# 2  [{'label': 'display', 'lat': 43.6546083, 'lng'...  43.654608 -79.385942
# 3  [{'label': 'display', 'lat': 43.658434, 'lng':...  43.658434 -79.387894
# 4  [{'label': 'display', 'lat': 43.65119976208405...  43.651200 -79.384520
#
#          neighborhood postalCode state                        id
# 0                 NaN    M5H 2M9    ON  4ab2d511f964a5209b6c20e3
# 1                 NaN    M5V 1Z1    ON  4b68aed1f964a520de862be3
# 2                 NaN    M5G 1R3    ON  52ce14b0498e50457ce11780
# 3                 NaN    M2M 2M2    ON  4f343a31e4b0230a3b337a90
# 4  Financial District        NaN    ON  5545d07e498e2facac03f666

# %%
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name              categories  \
# 0                    Sheraton Centre Toronto Hotel                   Hotel
# 1                   The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2      DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 3                                   VFM Test Hotel                   Hotel
# 4   Sheraton Centre Toronto Hotel - Grand Ballroom                Ballroom
# 5                                  Stathcona Hotel                   Hotel
# 6                Sheraton Centre Hotel Club Lounge                  Lounge
# 7    hilton hotel, richmondstreet E, 145,  toronto              Hotel Pool
# 8                                        650 Hotel                   Hotel
# 9     Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 10                              Shangri-La Toronto                   Hotel
# 11                                  Hilton Toronto                   Hotel
# 12                               Be SixFifty Hotel                   Hotel
# 13                           89 Chestnut Residence  College Residence Hall
# 14                   Op mijn hotelkamer In Toronto                   Hotel
# 15          Lobby Lounge at the Shangri-La Toronto                  Lounge
# 16                                  Fitness Centre                     Gym
# 17                                   Bistro on Two          Breakfast Spot
# 18                                  Fitness Centre                     Gym
# 19                                            Pool                    Pool
# 20                                   Kumar For Men             Men's Store
# 21                                  Grand Ballroom             Event Space
#
#                   address        lat        lng postalCode    state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9       ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1       ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3       ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2       ON
# 4   123 Queen Street West  43.651200 -79.384520        NaN       ON
# 5                     NaN  43.654947 -79.386359        NaN       ON
# 6                     NaN  43.651063 -79.384527    M5H 2M9       ON
# 7   Richmondstreet E, 145  43.650625 -79.385488        NaN       ON
# 8          650 Bay Street  43.657046 -79.384411        NaN       ON
# 9          525 Bay Street  43.654728 -79.382422    M5G 2L2       ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3       ON
# 11      145 Richmond St W  43.649946 -79.385479    M5H 2L2       ON
# 12         650 Bay Street  43.657120 -79.384560        NaN       ON
# 13        89 Chestnut St.  43.654160 -79.385291    M5G 1R1       ON
# 14                    NaN  43.654235 -79.386208        NaN       ON
# 15    188 University Ave.  43.649155 -79.386546    M5H 0A3       ON
# 16            525 Bay St.  43.654690 -79.381739    M5G 2L2       ON
# 17        123 Queen St. W  43.651011 -79.383658    M5H 2M9       ON
# 18        Sheraton Centre  43.650985 -79.384002    M5H 2M9       ON
# 19       Intercontinental  43.650975 -79.384053        NaN  Ontario
# 20        Sheraton Centre  43.651044 -79.383302    M5H 2M9       ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9       ON

# %%
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                             name              categories  \
# 0                  Sheraton Centre Toronto Hotel                   Hotel
# 1                 The Rex Hotel Jazz & Blues Bar               Jazz Club
# 2    DoubleTree by Hilton Hotel Toronto Downtown                   Hotel
# 3                                 VFM Test Hotel                   Hotel
# 9   Marriott Downtown at CF Toronto Eaton Centre                   Hotel
# 10                            Shangri-La Toronto                   Hotel
# 11                                Hilton Toronto                   Hotel
# 13                         89 Chestnut Residence  College Residence Hall
# 15        Lobby Lounge at the Shangri-La Toronto                  Lounge
# 16                                Fitness Centre                     Gym
# 17                                 Bistro on Two          Breakfast Spot
# 18                                Fitness Centre                     Gym
# 20                                 Kumar For Men             Men's Store
# 21                                Grand Ballroom             Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 1          194 Queen St W  43.650505 -79.388577    M5V 1Z1    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 9          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 13        89 Chestnut St.  43.654160 -79.385291    M5G 1R1    ON
# 15    188 University Ave.  43.649155 -79.386546    M5H 0A3    ON
# 16            525 Bay St.  43.654690 -79.381739    M5G 2L2    ON
# 17        123 Queen St. W  43.651011 -79.383658    M5H 2M9    ON
# 18        Sheraton Centre  43.650985 -79.384002    M5H 2M9    ON
# 20        Sheraton Centre  43.651044 -79.383302    M5H 2M9    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 3                                 VFM Test Hotel        Hotel
# 9   Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 10                            Shangri-La Toronto        Hotel
# 11                                Hilton Toronto        Hotel
# 21                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 9          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name   categories  \
# 0                  Sheraton Centre Toronto Hotel        Hotel
# 2    DoubleTree by Hilton Hotel Toronto Downtown        Hotel
# 3                                 VFM Test Hotel        Hotel
# 9   Marriott Downtown at CF Toronto Eaton Centre        Hotel
# 10                            Shangri-La Toronto        Hotel
# 11                                Hilton Toronto        Hotel
# 21                                Grand Ballroom  Event Space
#
#                   address        lat        lng postalCode state
# 0   123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 2     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 3          123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 9          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 10    188 University Ave.  43.649129 -79.386557    M5H 0A3    ON
# 11      145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON
# 21        123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON

# %%
hotelmap2 = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(df_hotels['lat'], df_hotels['lng'], 
                                           df_hotels['name'], df_hotels['categories'],
                                               df_hotels['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=15,
        popup=label,
        color='orange',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(hotelmap2)  
    
hotelmap2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 2M9']
df_hotel
# Out:
#                              name   categories                address  \
# 0   Sheraton Centre Toronto Hotel        Hotel  123 Queen Street West
# 21                 Grand Ballroom  Event Space        123 Queen St. W
#
#           lat        lng postalCode state
# 0   43.651144 -79.384329    M5H 2M9    ON
# 21  43.651217 -79.383771    M5H 2M9    ON

# %%
hotelmap1 = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(df_hotel['lat'], df_hotel['lng'], 
                                           df_hotel['name'], df_hotel['categories'],
                                               df_hotel['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=15,
        popup=label,
        color='orange',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(hotelmap1)  
    
hotelmap1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Parks around Toronto

# %%
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QTM50SKMXJ1SVI5NF0ZNAFVGLQQ5TQS4GC0BQ3YPZKBHGBRE&client_secret=BY42AUCWXDZ2AIGL11FSR3LYROTHMIATTTGS14GPT2SHOIQK&ll=43.653963,-79.387207&v=20180605&query=Park&radius=10000&limit=35'

# %%
presults = requests.get(url).json()
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 1  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
#
#                          id              location.address location.cc  \
# 0  4b54deadf964a520a3d027e3                           NaN          CA
# 1  4b170e47f964a5208cc123e3            691 University Ave          CA
# 2  4ad4c05ef964a520bdf620e3            1053 Dundas St. W.          CA
# 3  4bb3c91a2397b7134d9f38b3                   Spadina Ave          CA
# 4  4b797b48f964a520c6fb2ee3  btwn Bellevue & Augusta Ave.          CA
#
#   location.city location.country location.crossStreet  location.distance  \
# 0       Toronto           Canada                  NaN                423
# 1       Toronto           Canada        at College St                716
# 2       Toronto           Canada    at Gore Vale Ave.               2271
# 3       Toronto           Canada   at Wellington St W               1223
# 4       Toronto           Canada                  NaN               1208
#
#                            location.formattedAddress  \
# 0  [btwn College, University, Queen & Spadina, To...
# 1  [691 University Ave (at College St), Toronto O...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [Spadina Ave (at Wellington St W), Toronto ON,...
# 4  [btwn Bellevue & Augusta Ave., Toronto ON M5T ...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65248755299856...     43.652488
# 1  [{'label': 'display', 'lat': 43.66000635700919...     43.660006
# 2  [{'label': 'display', 'lat': 43.64707192840234...     43.647072
# 3  [{'label': 'display', 'lat': 43.64422227794523...     43.644222
# 4  [{'label': 'display', 'lat': 43.65361021143256...     43.653610
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0    -79.392053                   NaN                 NaN             ON
# 1    -79.390272                   NaN             M5G 2P1             ON
# 2    -79.413756                   NaN             M5H 2N2             ON
# 3    -79.394230                   NaN                 NaN             ON
# 4    -79.402199                   NaN             M5T 2N4             ON
#
#                           name    referralId venuePage.id
# 0                  Grange Park  v-1568536758          NaN
# 1  Queen's Park Subway Station  v-1568536758          NaN
# 2       Trinity Bellwoods Park  v-1568536758          NaN
# 3         Clarence Square Park  v-1568536758          NaN
# 4         Bellevue Square Park  v-1568536758          NaN

# %%
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                           name     categories                       address  \
# 0                  Grange Park           Park                           NaN
# 1  Queen's Park Subway Station  Metro Station            691 University Ave
# 2       Trinity Bellwoods Park           Park            1053 Dundas St. W.
# 3         Clarence Square Park           Park                   Spadina Ave
# 4         Bellevue Square Park           Park  btwn Bellevue & Augusta Ave.
#
#    cc     city country         crossStreet  distance  \
# 0  CA  Toronto  Canada                 NaN       423
# 1  CA  Toronto  Canada       at College St       716
# 2  CA  Toronto  Canada   at Gore Vale Ave.      2271
# 3  CA  Toronto  Canada  at Wellington St W      1223
# 4  CA  Toronto  Canada                 NaN      1208
#
#                                     formattedAddress  \
# 0  [btwn College, University, Queen & Spadina, To...
# 1  [691 University Ave (at College St), Toronto O...
# 2  [1053 Dundas St. W. (at Gore Vale Ave.), Toron...
# 3  [Spadina Ave (at Wellington St W), Toronto ON,...
# 4  [btwn Bellevue & Augusta Ave., Toronto ON M5T ...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65248755299856...  43.652488 -79.392053
# 1  [{'label': 'display', 'lat': 43.66000635700919...  43.660006 -79.390272
# 2  [{'label': 'display', 'lat': 43.64707192840234...  43.647072 -79.413756
# 3  [{'label': 'display', 'lat': 43.64422227794523...  43.644222 -79.394230
# 4  [{'label': 'display', 'lat': 43.65361021143256...  43.653610 -79.402199
#
#   neighborhood postalCode state                        id
# 0          NaN        NaN    ON  4b54deadf964a520a3d027e3
# 1          NaN    M5G 2P1    ON  4b170e47f964a5208cc123e3
# 2          NaN    M5H 2N2    ON  4ad4c05ef964a520bdf620e3
# 3          NaN        NaN    ON  4bb3c91a2397b7134d9f38b3
# 4          NaN    M5T 2N4    ON  4b797b48f964a520c6fb2ee3

# %%
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id','neighborhood'], axis=1)
clean_park_dataframe2
# Out:
#                                        name  \
# 0                               Grange Park
# 1               Queen's Park Subway Station
# 2                    Trinity Bellwoods Park
# 3                      Clarence Square Park
# 4                      Bellevue Square Park
# 5             Crunch Fitness - College Park
# 6                               Berczy Park
# 7                             One Park Lane
# 8                              Queen's Park
# 9                                  HTO Park
# 10        St. Andrews Playground / Dog Park
# 11         Residences at College Park North
# 12                      Riverdale Park East
# 13       TTC Streetcar #403 - Victoria park
# 14                                High Park
# 15                       Canoe Landing Park
# 16                             Stanley Park
# 17                      Riverdale Park West
# 18                          Coronation Park
# 19                  Stanley Park (Dog Park)
# 20                             College Park
# 21                          Roundhouse Park
# 22                   Physiomed College Park
# 23                        Barbara Hall Park
# 24         Toothworks - College Park Dental
# 25                     Aura at College Park
# 26                  Cawthra Square Dog Park
# 27                              Regent Park
# 28                       Battery Park Tower
# 29                  Moss Park Tennis Courts
# 30                      RBC WaterPark Place
# 31                   Parliament Square Park
# 32                      Harbour Square Park
# 33                          Winchester Park
# 34  GoodLife Fitness Toronto Bloor and Park
#
#                                   categories                       address  \
# 0                                       Park                           NaN
# 1                              Metro Station            691 University Ave
# 2                                       Park            1053 Dundas St. W.
# 3                                       Park                   Spadina Ave
# 4                                       Park  btwn Bellevue & Augusta Ave.
# 5                       Gym / Fitness Center              382 Yonge Street
# 6                                       Park        35 Wellington St. East
# 7   Residential Building (Apartment / Condo)                 280 Simcoe St
# 8                                       Park               University Ave.
# 9                                       Park                  Queen's Quay
# 10                                      Park      450 Adelaide Street West
# 11  Residential Building (Apartment / Condo)                   763 Bay St.
# 12                                      Park             550 Broadview Ave
# 13                        Light Rail Station                           NaN
# 14                                      Park              1873 Bloor St. W
# 15                                      Park             50 Fort York Blvd
# 16                                      Park              King Street West
# 17                                      Park               500 Gerrard St.
# 18                                      Park        711 Lake Shore Blvd. W
# 19                                   Dog Run              King Street West
# 20                             Shopping Mall                  444 Yonge St
# 21                                      Park             255 Bremner Blvd.
# 22                            Medical Center                  382 Yonge St
# 23                                      Park             519 Church Street
# 24                          Dentist's Office        444 Yonge St, Unit M16
# 25  Residential Building (Apartment / Condo)                     Yonge St.
# 26                                   Dog Run                519 Church St.
# 27                                      Park              620 Dundas St E.
# 28  Residential Building (Apartment / Condo)           50 Lynn Williams St
# 29                              Tennis Court                     Moss Park
# 30                                    Office                88 Queens Quay
# 31                                      Park          44 Parliament Street
# 32                                      Park           25 Queens Quay West
# 33                                Playground            530 Ontario Street
# 34                                       Gym                     8 Park Rd
#
#           lat        lng postalCode state
# 0   43.652488 -79.392053        NaN    ON
# 1   43.660006 -79.390272    M5G 2P1    ON
# 2   43.647072 -79.413756    M5H 2N2    ON
# 3   43.644222 -79.394230        NaN    ON
# 4   43.653610 -79.402199    M5T 2N4    ON
# 5   43.659263 -79.382632    M5G 1S8    ON
# 6   43.648048 -79.375172        NaN    ON
# 7   43.655442 -79.390056    M5T 2Y5    ON
# 8   43.663946 -79.392180    M5R 2E8    ON
# 9   43.637949 -79.387820        NaN    ON
# 10  43.647388 -79.398752        NaN    ON
# 11  43.659822 -79.385159    M5G 2R3    ON
# 12  43.669951 -79.355493    M4K 2P1    ON
# 13  43.650735 -79.386921        NaN    ON
# 14  43.646479 -79.463425    M6R 2Z3    ON
# 15  43.638762 -79.397067    M5V 3Z1    ON
# 16  43.642395 -79.409330        NaN    ON
# 17  43.666048 -79.360941    M5A 2H3    ON
# 18  43.634553 -79.405403    M5V 3T7    ON
# 19  43.641668 -79.409269        NaN    ON
# 20  43.661237 -79.383603    M5B 2H4    ON
# 21  43.641745 -79.384279    M5V 3M9    ON
# 22  43.659240 -79.382860    M5B 1S8    ON
# 23  43.666728 -79.381084        NaN    ON
# 24  43.660009 -79.383905        NaN    ON
# 25  43.659198 -79.382863        NaN    ON
# 26  43.666583 -79.380040        NaN    ON
# 27  43.660383 -79.361810        NaN    ON
# 28  43.639024 -79.415510    M6K 3R9    ON
# 29  43.655337 -79.371923        NaN    ON
# 30  43.641075 -79.379154        NaN    ON
# 31  43.650264 -79.362195        NaN    ON
# 32  43.639253 -79.378395        NaN    ON
# 33  43.666231 -79.371631        NaN    ON
# 34  43.671302 -79.384691    M4W 3G8    ON

# %%
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                        name  \
# 1               Queen's Park Subway Station
# 2                    Trinity Bellwoods Park
# 4                      Bellevue Square Park
# 5             Crunch Fitness - College Park
# 7                             One Park Lane
# 8                              Queen's Park
# 11         Residences at College Park North
# 12                      Riverdale Park East
# 14                                High Park
# 15                       Canoe Landing Park
# 17                      Riverdale Park West
# 18                          Coronation Park
# 20                             College Park
# 21                          Roundhouse Park
# 22                   Physiomed College Park
# 28                       Battery Park Tower
# 34  GoodLife Fitness Toronto Bloor and Park
#
#                                   categories                       address  \
# 1                              Metro Station            691 University Ave
# 2                                       Park            1053 Dundas St. W.
# 4                                       Park  btwn Bellevue & Augusta Ave.
# 5                       Gym / Fitness Center              382 Yonge Street
# 7   Residential Building (Apartment / Condo)                 280 Simcoe St
# 8                                       Park               University Ave.
# 11  Residential Building (Apartment / Condo)                   763 Bay St.
# 12                                      Park             550 Broadview Ave
# 14                                      Park              1873 Bloor St. W
# 15                                      Park             50 Fort York Blvd
# 17                                      Park               500 Gerrard St.
# 18                                      Park        711 Lake Shore Blvd. W
# 20                             Shopping Mall                  444 Yonge St
# 21                                      Park             255 Bremner Blvd.
# 22                            Medical Center                  382 Yonge St
# 28  Residential Building (Apartment / Condo)           50 Lynn Williams St
# 34                                       Gym                     8 Park Rd
#
#           lat        lng postalCode state
# 1   43.660006 -79.390272    M5G 2P1    ON
# 2   43.647072 -79.413756    M5H 2N2    ON
# 4   43.653610 -79.402199    M5T 2N4    ON
# 5   43.659263 -79.382632    M5G 1S8    ON
# 7   43.655442 -79.390056    M5T 2Y5    ON
# 8   43.663946 -79.392180    M5R 2E8    ON
# 11  43.659822 -79.385159    M5G 2R3    ON
# 12  43.669951 -79.355493    M4K 2P1    ON
# 14  43.646479 -79.463425    M6R 2Z3    ON
# 15  43.638762 -79.397067    M5V 3Z1    ON
# 17  43.666048 -79.360941    M5A 2H3    ON
# 18  43.634553 -79.405403    M5V 3T7    ON
# 20  43.661237 -79.383603    M5B 2H4    ON
# 21  43.641745 -79.384279    M5V 3M9    ON
# 22  43.659240 -79.382860    M5B 1S8    ON
# 28  43.639024 -79.415510    M6K 3R9    ON
# 34  43.671302 -79.384691    M4W 3G8    ON

# %%
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 2   Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 4     Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 8             Queen's Park       Park               University Ave.
# 12     Riverdale Park East       Park             550 Broadview Ave
# 14               High Park       Park              1873 Bloor St. W
# 15      Canoe Landing Park       Park             50 Fort York Blvd
# 17     Riverdale Park West       Park               500 Gerrard St.
# 18         Coronation Park       Park        711 Lake Shore Blvd. W
# 21         Roundhouse Park       Park             255 Bremner Blvd.
#
#           lat        lng postalCode state
# 2   43.647072 -79.413756    M5H 2N2    ON
# 4   43.653610 -79.402199    M5T 2N4    ON
# 8   43.663946 -79.392180    M5R 2E8    ON
# 12  43.669951 -79.355493    M4K 2P1    ON
# 14  43.646479 -79.463425    M6R 2Z3    ON
# 15  43.638762 -79.397067    M5V 3Z1    ON
# 17  43.666048 -79.360941    M5A 2H3    ON
# 18  43.634553 -79.405403    M5V 3T7    ON
# 21  43.641745 -79.384279    M5V 3M9    ON

# %%
parkmap1 = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(df_park['lat'], df_park['lng'], 
                                           df_park['name'], df_park['categories'],
                                               df_park['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=15,
        popup=label,
        color='orange',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(parkmap1)  
    
parkmap1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Restaurants around Toronto

# %%
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QTM50SKMXJ1SVI5NF0ZNAFVGLQQ5TQS4GC0BQ3YPZKBHGBRE&client_secret=BY42AUCWXDZ2AIGL11FSR3LYROTHMIATTTGS14GPT2SHOIQK&ll=43.653963,-79.387207&v=20180605&query=Restaurant&radius=10000&limit=35'

# %%
Rresults = requests.get(url).json()
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 1  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c060f964a5207ff720e3     323 Spadina Ave.          CA       Toronto
# 1  4b266f05f964a520657b24e3      266 Spadina Ave          CA       Toronto
# 2  4ae29812f964a520288f21e3     309 Spadina Ave.          CA       Toronto
# 3  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 4  4b223f5af964a520ba4424e3        225 Frnt St W          CA       Toronto
#
#   location.country            location.crossStreet  location.distance  \
# 0           Canada                   at D'Arcy St.                922
# 1           Canada                  at Willison Sq                892
# 2           Canada  btwn Dundas St. W & D'Arcy St.                896
# 3           Canada                             NaN                145
# 4           Canada                             NaN               1039
#
#                            location.formattedAddress  \
# 0  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 1  [266 Spadina Ave (at Willison Sq), Toronto ON ...
# 2  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 3  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 4        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 1  [{'label': 'display', 'lat': 43.6522783893466,...     43.652278
# 2  [{'label': 'display', 'lat': 43.65386562507761...     43.653866
# 3  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 4  [{'label': 'display', 'lat': 43.64474919591934...     43.644749
#
#    location.lng   location.neighborhood location.postalCode location.state  \
# 0    -79.398650       Kensington Market             M5T 2E9             ON
# 1    -79.398039                     NaN             M5T 2E4             ON
# 2    -79.398334                     NaN             M5T 2E6             ON
# 3    -79.385931                     NaN             M5G 1R3             ON
# 4    -79.385113  Entertainment District             M5V 2X3             ON
#
#                               name    referralId venuePage.id
# 0           Rol San Restaurant 龍笙棧  v-1568537087          NaN
# 1   Goldstone Noodle Restaurant 金石  v-1568537087          NaN
# 2          Swatow Restaurant 汕頭小食家  v-1568537087          NaN
# 3  Hemispheres Restaurant & Bistro  v-1568537087          NaN
# 4           Azure Restaurant & Bar  v-1568537087    136175835

# %%
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                               name           categories              address  \
# 0           Rol San Restaurant 龍笙棧   Dim Sum Restaurant     323 Spadina Ave.
# 1   Goldstone Noodle Restaurant 金石         Noodle House      266 Spadina Ave
# 2          Swatow Restaurant 汕頭小食家   Chinese Restaurant     309 Spadina Ave.
# 3  Hemispheres Restaurant & Bistro  American Restaurant  110 Chestnut Street
# 4           Azure Restaurant & Bar           Restaurant        225 Frnt St W
#
#    cc     city country                     crossStreet  distance  \
# 0  CA  Toronto  Canada                   at D'Arcy St.       922
# 1  CA  Toronto  Canada                  at Willison Sq       892
# 2  CA  Toronto  Canada  btwn Dundas St. W & D'Arcy St.       896
# 3  CA  Toronto  Canada                             NaN       145
# 4  CA  Toronto  Canada                             NaN      1039
#
#                                     formattedAddress  \
# 0  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 1  [266 Spadina Ave (at Willison Sq), Toronto ON ...
# 2  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 3  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 4        [225 Frnt St W, Toronto ON M5V 2X3, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65431754076345...  43.654318 -79.398650
# 1  [{'label': 'display', 'lat': 43.6522783893466,...  43.652278 -79.398039
# 2  [{'label': 'display', 'lat': 43.65386562507761...  43.653866 -79.398334
# 3  [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 4  [{'label': 'display', 'lat': 43.64474919591934...  43.644749 -79.385113
#
#              neighborhood postalCode state                        id
# 0       Kensington Market    M5T 2E9    ON  4ad4c060f964a5207ff720e3
# 1                     NaN    M5T 2E4    ON  4b266f05f964a520657b24e3
# 2                     NaN    M5T 2E6    ON  4ae29812f964a520288f21e3
# 3                     NaN    M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 4  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3

# %%
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 1                   Goldstone Noodle Restaurant 金石             Noodle House
# 2                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 3                  Hemispheres Restaurant & Bistro      American Restaurant
# 4                           Azure Restaurant & Bar               Restaurant
# 5               Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 6                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 7                                   360 Restaurant                 Wine Bar
# 8                            Victoria's Restaurant               Restaurant
# 9                   The Hot House Restaurant & Bar      American Restaurant
# 10                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 11              North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 12                         The Lakeview Restaurant                    Diner
# 13                         Victor Restaurant & Bar                      Bar
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15                    Aroma Fine Indian Restaurant        Indian Restaurant
# 16              Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 17                           ONE Restaurant/Lounge  New American Restaurant
# 18                  Insomnia Restaurant and Lounge               Restaurant
# 19  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 20         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 21                   Green Tea Restaurant Downtown       Chinese Restaurant
# 22             Richtree Natural Market Restaurants               Restaurant
# 23                     Woodlot Restaurant & Bakery  New American Restaurant
# 24               El Rancho Restaurant & Night Club                Nightclub
# 25                      Wah Too Seafood Restaurant       Chinese Restaurant
# 26                               Studio Restaurant           Breakfast Spot
# 27                           Sightlines Restaurant      American Restaurant
# 28                               Tundra Restaurant               Restaurant
# 29               Kensington Cornerstone Restaurant           Breakfast Spot
# 30                     Cottage Restaurant & Lounge          Thai Restaurant
# 31                                Union Restaurant  New American Restaurant
# 32                   Micheal's Restaurant and Deli                      Bar
# 33                            Montecito Restaurant               Restaurant
# 34                 Kyoto House Japanese Restaurant         Sushi Restaurant
#
#                             address        lat        lng postalCode state
# 0                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 1                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 2                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 3               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 4                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 5                  280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 6                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 7                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 8               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 9                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 10                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 11                   476 Dundas St.  43.653185 -79.396677        NaN    ON
# 12                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 13                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 16               988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 17                116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 18                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 19            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 20                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 21  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 22                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 23              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 24                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 25                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 26                   389 Church St.  43.661500 -79.379319        M5B    ON
# 27                    Rogers Centre  43.641635 -79.389365        NaN    ON
# 28         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 29               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 30                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 31                72 Ossington Ave.  43.645860 -79.419532        NaN    ON
# 32                   566 Queen St W  43.647289 -79.403493        NaN    ON
# 33                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 34              143 Dundas St. West  43.655381 -79.385270        NaN    ON

# %%
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name               categories  \
# 0                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 1                   Goldstone Noodle Restaurant 金石             Noodle House
# 2                          Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 3                  Hemispheres Restaurant & Bistro      American Restaurant
# 4                           Azure Restaurant & Bar               Restaurant
# 6                         New Sky Restaurant 小沙田食家       Chinese Restaurant
# 7                                   360 Restaurant                 Wine Bar
# 8                            Victoria's Restaurant               Restaurant
# 9                   The Hot House Restaurant & Bar      American Restaurant
# 10                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 12                         The Lakeview Restaurant                    Diner
# 13                         Victor Restaurant & Bar                      Bar
# 14                        Ka Chi Korean Restaurant        Korean Restaurant
# 15                    Aroma Fine Indian Restaurant        Indian Restaurant
# 18                  Insomnia Restaurant and Lounge               Restaurant
# 19  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 20         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 21                   Green Tea Restaurant Downtown       Chinese Restaurant
# 22             Richtree Natural Market Restaurants               Restaurant
# 23                     Woodlot Restaurant & Bakery  New American Restaurant
# 24               El Rancho Restaurant & Night Club                Nightclub
# 25                      Wah Too Seafood Restaurant       Chinese Restaurant
# 26                               Studio Restaurant           Breakfast Spot
# 28                               Tundra Restaurant               Restaurant
# 29               Kensington Cornerstone Restaurant           Breakfast Spot
# 30                     Cottage Restaurant & Lounge          Thai Restaurant
# 33                            Montecito Restaurant               Restaurant
#
#                             address        lat        lng postalCode state
# 0                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 1                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 2                  309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 3               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 4                     225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 6                  353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 7                    301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 8               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 9                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 10                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 12                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 13                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 14                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 15                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 18                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 19            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 20                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 21  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 22                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 23              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 24                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 25                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 26                   389 Church St.  43.661500 -79.379319        M5B    ON
# 28         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 29               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 30                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 33                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON

# %%
restmap1 = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(df_Restaurant['lat'], df_Restaurant['lng'], 
                                           df_Restaurant['name'], df_Restaurant['categories'],
                                               df_Restaurant['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=15,
        popup=label,
        color='orange',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(restmap1)  
    
restmap1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Cafeteria around Toronto

# %%
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QTM50SKMXJ1SVI5NF0ZNAFVGLQQ5TQS4GC0BQ3YPZKBHGBRE&client_secret=BY42AUCWXDZ2AIGL11FSR3LYROTHMIATTTGS14GPT2SHOIQK&ll=43.653963,-79.387207&v=20180605&query=Cafeteria&radius=10000&limit=35'

# %%
cresults = requests.get(url).json()
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...    False
# 4  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
#
#                          id                           location.address  \
# 0  4f9165bde4b04fef0087e4e2  The Hospital for Sick Children (SickKids)
# 1  528e99a211d262edc3708a6f                            388 Spadina Ave
# 2  4ec2b68a8231a83de8c45191                             100 McCaul St.
# 3  56b2c90a498e9f0e73d6bed6                             974 College St
# 4  53bd6dfe498e6c1d3bc9333e                                        NaN
#
#   location.cc location.city location.country location.crossStreet  \
# 0          CA       Toronto           Canada                  NaN
# 1          CA       Toronto           Canada         at Nassau St
# 2          CA       Toronto           Canada         Second Floor
# 3          CA       Toronto           Canada                  NaN
# 4          CA       Toronto           Canada                  NaN
#
#    location.distance                          location.formattedAddress  \
# 0                372  [The Hospital for Sick Children (SickKids), To...
# 1                977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2                389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 3               3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 4                260                               [Toronto ON, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...     43.657209
# 1  [{'label': 'display', 'lat': 43.65545427446646...     43.655454
# 2  [{'label': 'display', 'lat': 43.65278016892648...     43.652780
# 3  [{'label': 'display', 'lat': 43.65341883567197...     43.653419
# 4  [{'label': 'display', 'lat': 43.655657, 'lng':...     43.655657
#
#    location.lng location.postalCode location.state  \
# 0    -79.386063                 NaN             ON
# 1    -79.399163             M5T 2G5             ON
# 2    -79.391762                 NaN             ON
# 3    -79.427678             M6H 1A5             ON
# 4    -79.389443                 NaN             ON
#
#                             name    referralId
# 0                      Cafeteria  v-1568537248
# 1              Stay Cafeteria 慢走  v-1568537248
# 2                 OCAD Cafeteria  v-1568537248
# 3                      Cafeteria  v-1568537248
# 4  Industrial Alliance Cafeteria  v-1568537248

# %%
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                 OCAD Cafeteria     College Cafeteria
# 3                      Cafeteria    Mexican Restaurant
# 4  Industrial Alliance Cafeteria             Cafeteria
#
#                                      address  cc     city country  \
# 0  The Hospital for Sick Children (SickKids)  CA  Toronto  Canada
# 1                            388 Spadina Ave  CA  Toronto  Canada
# 2                             100 McCaul St.  CA  Toronto  Canada
# 3                             974 College St  CA  Toronto  Canada
# 4                                        NaN  CA  Toronto  Canada
#
#     crossStreet  distance                                   formattedAddress  \
# 0           NaN       372  [The Hospital for Sick Children (SickKids), To...
# 1  at Nassau St       977  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2  Second Floor       389  [100 McCaul St. (Second Floor), Toronto ON, Ca...
# 3           NaN      3260       [974 College St, Toronto ON M6H 1A5, Canada]
# 4           NaN       260                               [Toronto ON, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...  43.657209 -79.386063
# 1  [{'label': 'display', 'lat': 43.65545427446646...  43.655454 -79.399163
# 2  [{'label': 'display', 'lat': 43.65278016892648...  43.652780 -79.391762
# 3  [{'label': 'display', 'lat': 43.65341883567197...  43.653419 -79.427678
# 4  [{'label': 'display', 'lat': 43.655657, 'lng':...  43.655657 -79.389443
#
#   postalCode state                        id
# 0        NaN    ON  4f9165bde4b04fef0087e4e2
# 1    M5T 2G5    ON  528e99a211d262edc3708a6f
# 2        NaN    ON  4ec2b68a8231a83de8c45191
# 3    M6H 1A5    ON  56b2c90a498e9f0e73d6bed6
# 4        NaN    ON  53bd6dfe498e6c1d3bc9333e

# %%
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                      name            categories  \
# 0                               Cafeteria  Fast Food Restaurant
# 1                       Stay Cafeteria 慢走      Asian Restaurant
# 2                          OCAD Cafeteria     College Cafeteria
# 3                               Cafeteria    Mexican Restaurant
# 4           Industrial Alliance Cafeteria             Cafeteria
# 5                         Dears Cafeteria          Dessert Shop
# 6                 Chestnut Tree Cafeteria             Cafeteria
# 7                         Sears Cafeteria            Food Court
# 8           De La Salle College Cafeteria     College Cafeteria
# 9                       Med Sci Cafeteria     College Cafeteria
# 10                  Ryerson Hub Cafeteria     College Cafeteria
# 11                     SickKids Cafeteria            Food Court
# 12              Macdonald Block Cafeteria             Cafeteria
# 13                      Robarts Cafeteria     College Cafeteria
# 14                          OMP Cafeteria             Cafeteria
# 15                       Rogers Cafeteria            Food Court
# 16                      Choices Cafeteria            Food Court
# 17    Cafeteria, Lawrence Park Collegiate           High School
# 18                       Kasala Cafeteria    African Restaurant
# 19    Cafeteria, Lawrence Park Collegiate           Event Space
# 20                                The Hub     College Cafeteria
# 21               Estonian House Cafeteria                  Café
# 22                             Marketeria            Restaurant
# 23                           CC Cafeteria     College Cafeteria
# 24  George Brown College St. James Campus     Community College
# 25                               One Hour    Chinese Restaurant
# 26                             Radio Cafe            Food Court
# 27                          Innis College        Student Center
# 28     Lawrence Park Collegiate Cafeteria           High School
# 29                           L5 Cafeteria      Cuban Restaurant
# 30  6th Floor Cafeteria 12 Concorde Place                  Café
# 31          Westpark Healthcare Cafeteria                  Café
# 32                      Glendon Cafeteria     College Cafeteria
# 33                          Upstairs Cafe   Corporate Cafeteria
# 34                     Eurest Dishes Cafe            Food Court
#
#                                       address        lat        lng  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                             388 Spadina Ave  43.655454 -79.399163
# 2                              100 McCaul St.  43.652780 -79.391762
# 3                              974 College St  43.653419 -79.427678
# 4                                         NaN  43.655657 -79.389443
# 5                                         NaN  43.654179 -79.392555
# 6                          89 Chestnut Street  43.648231 -79.384045
# 7                                       Yonge  43.656038 -79.380672
# 8                          131 Farnham Avenue  43.683003 -79.397815
# 9                                         NaN  43.660260 -79.392977
# 10                           350 Victoria St.  43.658475 -79.377653
# 11                      555 University Avenue  43.657584 -79.375652
# 12                                        NaN  43.663212 -79.388062
# 13                         130 St. George St.  43.664864 -79.399766
# 14                           1 Mount Pleasant  43.669801 -79.379790
# 15                                        NaN  43.669904 -79.379748
# 16                         200 Bloor Street E  43.671411 -79.381849
# 17                                        NaN  43.721732 -79.409600
# 18                                      Bloor  43.660759 -79.424018
# 19                                        NaN  43.723286 -79.412222
# 20                           350 Victoria St.  43.658585 -79.380622
# 21                       958 Broadview avenue  43.681763 -79.358246
# 22                                30 Bond St.  43.653585 -79.378843
# 23                             951 Carlaw Ave  43.684631 -79.348862
# 24                             51 Dockside Dr  43.644163 -79.366375
# 25                           435 Spadina Ave.  43.657399 -79.399649
# 26                          333 Bloor st east  43.671696 -79.380617
# 27                               2 Sussex Ave  43.665556 -79.399298
# 28                                        NaN  43.722757 -79.413734
# 29                                        NaN  43.723019 -79.345012
# 30                          12 Concorde Place  43.721861 -79.329339
# 31                          82 Buttonwood Ave  43.687714 -79.508885
# 32                           2275 Bayview Ave  43.727383 -79.378080
# 33                     26 Prince Andrew Place  43.725383 -79.345481
# 34                          100 Wynford Drive  43.727279 -79.332272
#
#    postalCode state
# 0         NaN    ON
# 1     M5T 2G5    ON
# 2         NaN    ON
# 3     M6H 1A5    ON
# 4         NaN    ON
# 5         NaN   NaN
# 6         NaN    ON
# 7         NaN    ON
# 8     M4V 1H7    ON
# 9         NaN    ON
# 10        NaN    ON
# 11        NaN    ON
# 12        NaN   NaN
# 13        NaN    ON
# 14        NaN    ON
# 15        NaN    ON
# 16        NaN    ON
# 17        NaN   NaN
# 18        NaN   NaN
# 19        NaN   NaN
# 20    M5B 2K3    ON
# 21        NaN    ON
# 22    M5B 1W8    ON
# 23        NaN    ON
# 24    M5A 0B6    ON
# 25    M5T 2T6    ON
# 26        NaN    ON
# 27    M5S 1J5    ON
# 28        NaN    ON
# 29        NaN   NaN
# 30    m3c 3k7    ON
# 31        NaN    ON
# 32        NaN    ON
# 33    M3C 2H4    ON
# 34    M3C 4B4    ON

# %%
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                      name           categories  \
# 1                       Stay Cafeteria 慢走     Asian Restaurant
# 3                               Cafeteria   Mexican Restaurant
# 8           De La Salle College Cafeteria    College Cafeteria
# 20                                The Hub    College Cafeteria
# 22                             Marketeria           Restaurant
# 24  George Brown College St. James Campus    Community College
# 25                               One Hour   Chinese Restaurant
# 27                          Innis College       Student Center
# 30  6th Floor Cafeteria 12 Concorde Place                 Café
# 33                          Upstairs Cafe  Corporate Cafeteria
# 34                     Eurest Dishes Cafe           Food Court
#
#                    address        lat        lng postalCode state
# 1          388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 3           974 College St  43.653419 -79.427678    M6H 1A5    ON
# 8       131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 20        350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 22             30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 24          51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 25        435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 27            2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 30       12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 33  26 Prince Andrew Place  43.725383 -79.345481    M3C 2H4    ON
# 34       100 Wynford Drive  43.727279 -79.332272    M3C 4B4    ON

# %%
cafmap1 = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(df_Cafeteria['lat'], df_Cafeteria['lng'], 
                                           df_Cafeteria['name'], df_Cafeteria['categories'],
                                               df_Cafeteria['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=15,
        popup=label,
        color='orange',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(cafmap1)  
    
cafmap1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Shopping Stores around Torornto

# %%
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QTM50SKMXJ1SVI5NF0ZNAFVGLQQ5TQS4GC0BQ3YPZKBHGBRE&client_secret=BY42AUCWXDZ2AIGL11FSR3LYROTHMIATTTGS14GPT2SHOIQK&ll=43.653963,-79.387207&v=20180605&query=Shopping&radius=1000&limit=35'

# %%
sresults = requests.get(url).json()
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...    False
#
#                          id    location.address location.cc location.city  \
# 0  4ad4c062f964a520fcf720e3     280 Spadina Ave          CA       Toronto
# 1  4ad77a12f964a520260b21e3        220 Yonge St          CA       Toronto
# 2  4b9e86dff964a520e6eb36e3  66 Wellington St W          CA       Toronto
# 3  5840cafe06f1a34af80cc609    176 Yonge Street          CA       Toronto
# 4  4b83d653f964a520d91231e3   461 King St. West          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada       at Dundas St W                897
# 1           Canada  btwn Queen & Dundas                535
# 2           Canada    btw York & Bay St                908
# 3           Canada    Queen Street West                688
# 4           Canada                  NaN                974
#
#                            location.formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...     43.652774
# 1                                                NaN     43.654265
# 2  [{'label': 'display', 'lat': 43.64718424611984...     43.647184
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...     43.651810
# 4  [{'label': 'display', 'lat': 43.64795765580337...     43.647958
#
#    location.lng          location.neighborhood location.postalCode  \
# 0    -79.398222                            NaN             M5T 3A5
# 1    -79.380567  Downtown Toronto, Toronto, ON             M5B 2H1
# 2    -79.380932                            NaN             M5K 1A1
# 3    -79.379192                            NaN             M5C 2L7
# 4    -79.396006                            NaN             M5V 1K4
#
#   location.state                                        name    referralId
# 0             ON                Dragon City Shopping Mall 龍城  v-1568537429
# 1             ON                     CF Toronto Eaton Centre  v-1568537429
# 2             ON                TD Centre Shopping Concourse  v-1568537429
# 3             ON  Saks Fifth Avenue Club - Personal Shopping  v-1568537429
# 4             ON             Yellow Pages - RedFlagDeals.com  v-1568537429

# %%
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address  cc     city country          crossStreet  distance  \
# 0     280 Spadina Ave  CA  Toronto  Canada       at Dundas St W       897
# 1        220 Yonge St  CA  Toronto  Canada  btwn Queen & Dundas       535
# 2  66 Wellington St W  CA  Toronto  Canada    btw York & Bay St       908
# 3    176 Yonge Street  CA  Toronto  Canada    Queen Street West       688
# 4   461 King St. West  CA  Toronto  Canada                  NaN       974
#
#                                     formattedAddress  \
# 0  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 2  [66 Wellington St W (btw York & Bay St), Toron...
# 3  [176 Yonge Street (Queen Street West), Toronto...
# 4    [461 King St. West, Toronto ON M5V 1K4, Canada]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...  43.652774 -79.398222
# 1                                                NaN  43.654265 -79.380567
# 2  [{'label': 'display', 'lat': 43.64718424611984...  43.647184 -79.380932
# 3  [{'label': 'display', 'lat': 43.65181, 'lng': ...  43.651810 -79.379192
# 4  [{'label': 'display', 'lat': 43.64795765580337...  43.647958 -79.396006
#
#                     neighborhood postalCode state                        id
# 0                            NaN    M5T 3A5    ON  4ad4c062f964a520fcf720e3
# 1  Downtown Toronto, Toronto, ON    M5B 2H1    ON  4ad77a12f964a520260b21e3
# 2                            NaN    M5K 1A1    ON  4b9e86dff964a520e6eb36e3
# 3                            NaN    M5C 2L7    ON  5840cafe06f1a34af80cc609
# 4                            NaN    M5V 1K4    ON  4b83d653f964a520d91231e3

# %%
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1                     CF Toronto Eaton Centre     Shopping Mall
# 2                TD Centre Shopping Concourse     Shopping Mall
# 3  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 4             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1        220 Yonge St  43.654265 -79.380567    M5B 2H1    ON
# 2  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 3    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 4   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %%
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 1       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654265
# 2  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 1 -79.380567    M5B 2H1    ON
# 2 -79.380932    M5K 1A1    ON

# %%
shpmap1 = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(df_Shopping['lat'], df_Shopping['lng'], 
                                           df_Shopping['name'], df_Shopping['categories'],
                                               df_Shopping['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=15,
        popup=label,
        color='orange',
        fill=True,
        fill_color='red',
        fill_opacity=0.7,
        parse_html=False).add_to(shpmap1)  
    
shpmap1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Visualizing with maps

# %%
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                      name           categories  \
# 0           Sheraton Centre Toronto Hotel                Hotel
# 1                          Grand Ballroom          Event Space
# 2                       Stay Cafeteria 慢走     Asian Restaurant
# 3                               Cafeteria   Mexican Restaurant
# 4           De La Salle College Cafeteria    College Cafeteria
# 5                                 The Hub    College Cafeteria
# 6                              Marketeria           Restaurant
# 7   George Brown College St. James Campus    Community College
# 8                                One Hour   Chinese Restaurant
# 9                           Innis College       Student Center
# 10  6th Floor Cafeteria 12 Concorde Place                 Café
# 11                          Upstairs Cafe  Corporate Cafeteria
# 12                     Eurest Dishes Cafe           Food Court
# 13           Dragon City Shopping Mall 龍城        Shopping Mall
# 14                CF Toronto Eaton Centre        Shopping Mall
# 15           TD Centre Shopping Concourse        Shopping Mall
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.651144 -79.384329    M5H 2M9    ON
# 1          123 Queen St. W  43.651217 -79.383771    M5H 2M9    ON
# 2          388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 3           974 College St  43.653419 -79.427678    M6H 1A5    ON
# 4       131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 5         350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 6              30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 7           51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 8         435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 9             2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 10       12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 11  26 Prince Andrew Place  43.725383 -79.345481    M3C 2H4    ON
# 12       100 Wynford Drive  43.727279 -79.332272    M3C 4B4    ON
# 13         280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 14            220 Yonge St  43.654265 -79.380567    M5B 2H1    ON
# 15      66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON

# %%
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Visualizing Parks

# %%
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name               categories  \
# 0                           Trinity Bellwoods Park                     Park
# 1                             Bellevue Square Park                     Park
# 2                                     Queen's Park                     Park
# 3                              Riverdale Park East                     Park
# 4                                        High Park                     Park
# 5                               Canoe Landing Park                     Park
# 6                              Riverdale Park West                     Park
# 7                                  Coronation Park                     Park
# 8                                  Roundhouse Park                     Park
# 9                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 10                  Goldstone Noodle Restaurant 金石             Noodle House
# 11                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 12                 Hemispheres Restaurant & Bistro      American Restaurant
# 13                          Azure Restaurant & Bar               Restaurant
# 14                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 15                                  360 Restaurant                 Wine Bar
# 16                           Victoria's Restaurant               Restaurant
# 17                  The Hot House Restaurant & Bar      American Restaurant
# 18                   Hong Shing Chinese Restaurant       Chinese Restaurant
# 19                         The Lakeview Restaurant                    Diner
# 20                         Victor Restaurant & Bar                      Bar
# 21                        Ka Chi Korean Restaurant        Korean Restaurant
# 22                    Aroma Fine Indian Restaurant        Indian Restaurant
# 23                  Insomnia Restaurant and Lounge               Restaurant
# 24  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 25         Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 26                   Green Tea Restaurant Downtown       Chinese Restaurant
# 27             Richtree Natural Market Restaurants               Restaurant
# 28                     Woodlot Restaurant & Bakery  New American Restaurant
# 29               El Rancho Restaurant & Night Club                Nightclub
# 30                      Wah Too Seafood Restaurant       Chinese Restaurant
# 31                               Studio Restaurant           Breakfast Spot
# 32                               Tundra Restaurant               Restaurant
# 33               Kensington Cornerstone Restaurant           Breakfast Spot
# 34                     Cottage Restaurant & Lounge          Thai Restaurant
# 35                            Montecito Restaurant               Restaurant
# 36                               Stay Cafeteria 慢走         Asian Restaurant
# 37                                       Cafeteria       Mexican Restaurant
# 38                   De La Salle College Cafeteria        College Cafeteria
# 39                                         The Hub        College Cafeteria
# 40                                      Marketeria               Restaurant
# 41           George Brown College St. James Campus        Community College
# 42                                        One Hour       Chinese Restaurant
# 43                                   Innis College           Student Center
# 44           6th Floor Cafeteria 12 Concorde Place                     Café
# 45                                   Upstairs Cafe      Corporate Cafeteria
# 46                              Eurest Dishes Cafe               Food Court
#
#                             address        lat        lng postalCode state
# 0                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 1      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 2                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 3                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 4                  1873 Bloor St. W  43.646479 -79.463425    M6R 2Z3    ON
# 5                 50 Fort York Blvd  43.638762 -79.397067    M5V 3Z1    ON
# 6                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 7            711 Lake Shore Blvd. W  43.634553 -79.405403    M5V 3T7    ON
# 8                 255 Bremner Blvd.  43.641745 -79.384279    M5V 3M9    ON
# 9                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 10                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 11                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 12              110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 13                    225 Frnt St W  43.644749 -79.385113    M5V 2X3    ON
# 14                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 15                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 16              37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 17                     35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 18                  195 Dundas St W  43.654925 -79.387089    M5G 1C7    ON
# 19                1132 Dundas St. W  43.649435 -79.420390    M6J 1X2    ON
# 20                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 21                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 22                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 23                563 Bloor St West  43.665180 -79.410966    M5S 1Y6    ON
# 24            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 25                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 26  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 27                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 28              293 Palmerston Ave.  43.655765 -79.409929    M6J 2J3    ON
# 29                  430 College St.  43.656673 -79.407101    M5T 1T3    ON
# 30                   56 Centre Ave.  43.654833 -79.387206    M5G 1R5    ON
# 31                   389 Church St.  43.661500 -79.379319        M5B    ON
# 32         145 Richmond Street West  43.650010 -79.385608    M5H 2L2    ON
# 33               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 34                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 35                299 Adelaide St W  43.647644 -79.391069    M5V 1P7    ON
# 36                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 37                   974 College St  43.653419 -79.427678    M6H 1A5    ON
# 38               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 39                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 40                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 41                   51 Dockside Dr  43.644163 -79.366375    M5A 0B6    ON
# 42                 435 Spadina Ave.  43.657399 -79.399649    M5T 2T6    ON
# 43                     2 Sussex Ave  43.665556 -79.399298    M5S 1J5    ON
# 44                12 Concorde Place  43.721861 -79.329339    m3c 3k7    ON
# 45           26 Prince Andrew Place  43.725383 -79.345481    M3C 2H4    ON
# 46                100 Wynford Drive  43.727279 -79.332272    M3C 4B4    ON

# %%
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
